# %% [markdown]
# # Huntington's Disease Multi-Tissue Data
#
# Data sourced from Harvard Brain Tissue Resource Center - Merck Research Laboratories. Data available for [Cerebellum](http://gn1.genenetwork.org/webqtl/main.py?FormID=sharinginfo&GN_AccessionId=326), [Primary Visual Cortex](http://gn1.genenetwork.org/webqtl/main.py?FormID=sharinginfo&GN_AccessionId=327), and [Prefrontal Cortex](http://gn1.genenetwork.org/webqtl/main.py?FormID=sharinginfo&GN_AccessionId=328).

# %% [markdown]
# The GCN+VCDN model is trained with the following configurations in this notebook:
# 1. Cerebellum only
# 2. Primary Visual Cortex only
# 3. Prefrontal Cortex only
# 4. Cerbellum + Primary Visual Cortex + Prefrontal Cortex
# 5. Cerbellum + Primary Visual Cortex + Prefrontal Cortex + Inter-tissue pairwise interactions
# 6. Cerbellum + Primary Visual Cortex + Prefrontal Cortex + Intra-tissue pairwise interactions
# 7. Cerbellum + Primary Visual Cortex + Prefrontal Cortex + All Interactions (Inter-tissue and Intra-tissue)

# %% [markdown]
# ### Preliminaries

# %%
from main import train_model
import pandas as pd
import numpy as np
import random

import cufflinks as cf
import pathlib
# %matplotlib inline

import shap
shap.initjs()
import lime
import re
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
# SEED can be "random" or integer, if integer, it will be used as the seed for random, numpy, torch, and cuda
SEED = 42

# pre-processed data
cerebellum = "R/HBTRC/cerebellum_top.csv"
visualCortex = "R/HBTRC/visualCortex_top.csv"
prefrontalCortex = "R/HBTRC/prefrontalCortex_top.csv"
cerebellum_visual = "R/HBTRC/cere_visual.csv"
visual_prefrontal = "R/HBTRC/visual_prefrontal.csv"
prefrontal_cerebellum = "R/HBTRC/prefrontal_cerebellum.csv"
cerebellum_cerebellum = "R/HBTRC/cere_cere.csv"
visual_visual = "R/HBTRC/visual_visual.csv"
prefrontal_prefrontal = "R/HBTRC/prefrontal_prefrontal.csv"
meta_csv = "R/HBTRC/disease_class.csv"
trte_partition_file = "R/HBTRC/trte_partition.txt"

# change label from text to integer
label_dict = {"Normal   ":0, "Alzheimer's":1, "Huntington's":2}

doSMOTE = True # Boolean

# training parameters
num_epoch = 900
test_interval = 50
lr = 5e-4
weight_decay = 1e-3
dropout = 0.25
adj_parameter = 8 # average number of edge per node in adj matrix

# VERBOSE setting for print results
VERBOSE = 1 #0, only print final result; 1, only testing result; 2, training and testing result
OUTPUT_FILES = False #Boolean to determine whether to output loss and metrics as csv files
MAKE_PLOTS = False #Boolean to determine whether to output loss and metrics as plots in png format
feature_extract = [] #["lime", "shap"]
num_gcn = 2

# %% [markdown]
# ## 1. Cerebellum Only

# %%
RUN_TITLE = "This run includes only 1 GCN - Cerebellum"
RUN_TITLE_SHORT = "cerebellum"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [cerebellum, meta_csv, trte_partition_file]
GCN_names = ["cerebellum"]

COMBINER = False
feature_extract = []

# %%
losses_df, metrics_df, _, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")
# Out:
# 2021-06-22 15:48:15.825177
#
# This run includes only 1 GCN - Cerebellum
# SEED =  42
#
# Training...
#
# Test: Epoch 0
# Train Accuracy: 0.3400   Test ACC: 0.2133
# Train F1: 0.2778         Test F1: 0.0750
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# Normal    	           0.3333              0.6040              0.2933              0.0000
# Alzheimer's 	           0.3333              0.4027              0.4933              0.0000
# Huntington's 	           0.3333              0.0134              0.2133              1.0000
#
#
# Test: Epoch 50
# Train Accuracy: 0.8277   Test ACC: 0.5067
# Train F1: 0.8274         Test F1: 0.4347
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# ...

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. Primary Visual Cortex Only

# %%
RUN_TITLE = "This run includes only 1 GCN - Primary Visual Cortex"
RUN_TITLE_SHORT = "visualCortex"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [visualCortex, meta_csv, trte_partition_file]
GCN_names = ["visualCortex"]

COMBINER = False
feature_extract = []

# %%
losses_df, metrics_df, _, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")
# Out:
# 2021-06-22 15:23:03.569469
#
# This run includes only 1 GCNs - Primary Visual Cortex
# SEED =  42
#
# Training...
#
# Test: Epoch 0
# Train Accuracy: 0.3311   Test ACC: 0.2133
# Train F1: 0.2682         Test F1: 0.0750
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# Normal    	           0.3333              0.5839              0.2933              0.0000
# Alzheimer's 	           0.3333              0.4027              0.4933              0.0000
# Huntington's 	           0.3333              0.0067              0.2133              1.0000
#
#
# Test: Epoch 50
# Train Accuracy: 0.8166   Test ACC: 0.5733
# Train F1: 0.8167         Test F1: 0.5270
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# ...

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. Prefrontal Cortex Only

# %%
RUN_TITLE = "This run includes only 1 GCN - Prefrontal Cortex"
RUN_TITLE_SHORT = "prefrontalCortex"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [prefrontalCortex, meta_csv, trte_partition_file]
GCN_names = ["prefrontalCortex"]

COMBINER = False
feature_extract = []

# %%
losses_df, metrics_df, _, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")
# Out:
# 2021-06-22 15:25:46.545637
#
# This run includes only 1 GCNs - Prefrontal Cortex
# SEED =  42
#
# Training...
#
# Test: Epoch 0
# Train Accuracy: 0.3400   Test ACC: 0.2133
# Train F1: 0.2776         Test F1: 0.0750
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# Normal    	           0.3333              0.6107              0.2933              0.0000
# Alzheimer's 	           0.3333              0.3960              0.4933              0.0000
# Huntington's 	           0.3333              0.0134              0.2133              1.0000
#
#
# Test: Epoch 50
# Train Accuracy: 0.8188   Test ACC: 0.6933
# Train F1: 0.8159         Test F1: 0.6914
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# ...

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Cerbellum + Primary Visual Cortex + Prefrontal Cortex

# %%
RUN_TITLE = "This run includes 3 GCNs - Cerebellum, Primary Visual Cortex, and Prefrontal Cortex"
RUN_TITLE_SHORT = "primary_data"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [cerebellum, visualCortex, prefrontalCortex, meta_csv, trte_partition_file]
GCN_names = ["cerebellum", "visualCortex", "prefrontalCortex"]

COMBINER = "VCDN"
feature_extract = ["lime"]

# %%
losses_df, metrics_df, feature_imp, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")
feature_imp["lime"].to_csv("hbtrc_lime_primary.csv", index_label="features")
# Out:
# 2021-06-22 15:28:32.411088
#
# This run includes 3 GCNs - Cerebellum, Primary Visual Cortex, and Prefrontal Cortex
# SEED =  42
#
# Training...
#
# Test: Epoch 0
# Train Accuracy: 0.3356   Test ACC: 0.2533
# Train F1: 0.2621         Test F1: 0.1507
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ------------------------------------------------------------------------------------------
# Normal    	           0.3333              0.0000              0.2933              0.0000
# Alzheimer's 	           0.3333              0.3490              0.4933              0.0811
# Huntington's 	           0.3333              0.6577              0.2133              1.0000
#
#
# Test: Epoch 50
# Train Accuracy: 0.6152   Test ACC: 0.5200
# Train F1: 0.6053         Test F1: 0.5033
#
# Label        Train Distribution     Train Accuracy     Test Distribution     Test Accuracy
# ...

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5. Cerbellum + Primary Visual Cortex + Prefrontal Cortex + Inter-tissue pairwise interactions

# %%
RUN_TITLE = "This run includes 6 GCNs - Cerebellum, Primary Visual Cortex, Prefrontal Cortex, and the 3 inter-tissue pairwise interactions"
RUN_TITLE_SHORT = "inter-tissue-interactions"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [cerebellum, visualCortex, prefrontalCortex, cerebellum_visual, visual_prefrontal, prefrontal_cerebellum, meta_csv, trte_partition_file]
GCN_names = ["cerebellum", "visualCortex", "prefrontalCortex", "cere_vis", "vis_pre", "pre_cere"]

COMBINER = "VCDN"
feature_extract = []

# %%
losses_df, metrics_df, _, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")
# Out:
# 2021-07-07 17:54:17.741932
#
# This run includes 6 GCNs - Cerebellum, Primary Visual Cortex, Prefrontal Cortex, and the 3 inter-tissue pairwise interactions
# SEED =  42
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8a3df0611669> in <module>
#       3         dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
#       4         RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
# ----> 5         OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)
#       6
#       7 #losses_df.to_csv("losses.csv")
#
# ...

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])

# %% [markdown]
# ## 6. Cerbellum + Primary Visual Cortex + Prefrontal Cortex + Intra-tissue pairwise interactions

# %%
RUN_TITLE = "This run includes 3 GCNs - Cerebellum, Primary Visual Cortex, Prefrontal Cortex, and the three intra-tissue pairwise interactions"
RUN_TITLE_SHORT = "intra-tissue-interactions"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [cerebellum, visualCortex, prefrontalCortex, cerebellum_cerebellum, visual_visual, prefrontal_prefrontal, meta_csv, trte_partition_file]
GCN_names = ["cerebellum", "visualCortex", "prefrontalCortex", "cere_cere", "vis_vis", "pre_pre"]

COMBINER = "VCDN"
feature_extract = []

# %%
losses_df, metrics_df, _, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])

# %% [markdown]
# ## 7. Cerbellum + Primary Visual Cortex + Prefrontal Cortex + All Interactions

# %%
RUN_TITLE = "This run includes 3 GCNs - Cerebellum, Primary Visual Cortex, and Prefrontal Cortex"
RUN_TITLE_SHORT = "primary_data"

# load preprocessed data from csv
#load_list - list of csv files to laod. The -2 position should be meta_csv and -1 position should be trte_partition_file
load_list = [cerebellum, visualCortex, prefrontalCortex, cerebellum_visual, visual_prefrontal, prefrontal_cerebellum, cerebellum_cerebellum, visual_visual, prefrontal_prefrontal, meta_csv, trte_partition_file]
GCN_names = ["cerebellum", "visualCortex", "prefrontalCortex", "cere_vis", "vis_pre", "pre_cere", "cere_cere", "vis_vis", "pre_pre"]

COMBINER = "FullyConnected"
feature_extract = ["lime"]

# %%
losses_df, metrics_df, feature_imp, _, _ = train_model(load_list=load_list, label_dict=label_dict, GCN_names=GCN_names, COMBINER=COMBINER,
        SEED=SEED, num_epoch=num_epoch, test_interval=test_interval, lr=lr, weight_decay=weight_decay, 
        dropout=dropout, adj_parameter=adj_parameter, VERBOSE=VERBOSE, doSMOTE = doSMOTE,
        RUN_TITLE=RUN_TITLE, RUN_TITLE_SHORT=RUN_TITLE_SHORT,
        OUTPUT_FILES=OUTPUT_FILES, MAKE_PLOTS=MAKE_PLOTS, feature_extract=feature_extract, num_gcn=num_gcn)

#losses_df.to_csv("losses.csv")
#metrics_df.to_csv("metrics.csv")
feature_imp["lime"].to_csv("hbtrc_lime_all_int.csv", index_label="features")

# %%
metrics_df.plot(y=["train_accuracy", "test_accuracy", "train_F1", "test_F1"])
